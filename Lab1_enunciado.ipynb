# %% [markdown]
# <h1><center>Laboratorio 1: Git 👾</center></h1>
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos - Otoño 2025</strong></center>

# %% [markdown]
# ### Cuerpo Docente:
#
# - Profesores: Stefano Schiappacasse,Sebastián Tinoco
# - Auxiliares: Melanie Peña, Valentina Rojas
# - Ayudantes: Angelo Muñoz, Valentina Zúñiga

# %% [markdown]
# ### Equipo: **SUPER IMPORTANTE - notebooks sin nombre no serán revisados**
#
# - Nombre de alumno 1: Camila Salas Riffo
# - Nombre de alumno 2: Ignacio Negrete Silva

# %% [markdown]
# ### **Link de repositorio de GitHub:** [https://github.com/ignacio3645/MDS7202](https://github.com/ignacio3645/MDS7202)

# %% [markdown]
# ## Reglas:
#
# - **Grupos de 2 personas**
# - Fecha de entrega: 6 días de plazo con descuento de 1 punto por día. Entregas Martes a las 23:59.
# - Instrucciones del lab el viernes a las 16:15 en formato online. Asistencia no es obligatoria, pero se recomienda fuertemente asistir.
# - <u>Prohibidas las copias</u>. Cualquier intento de copia será debidamente penalizado con el reglamento de la escuela.
# - Tienen que subir el laboratorio a u-cursos y a su repositorio de github. Labs que no estén en u-cursos no serán revisados. Recuerden que el repositorio también tiene nota.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Pueden usar cualquier material del curso que estimen conveniente.

# %% [markdown]
# ## Objetivos del lab:
#
#
# - Conocer los elementos básicos que conformar `Git`
# - Clonar repositorios
# - Identificar ramas de un repositorio
# - Reconocer y solucionar problemas entre ramas
# - Subir cambios a un repositorio

# %% [markdown]
# ## Parte 1: Conocimiento Teórico (2.5 pts)
#
# <p align="center">
#   <img src="https://cdn.thedesigninspiration.com/wp-content/uploads/sites/3/2019/04/macintosh-hdusersbrittanyloefflerdownloadsanig-1.gif" width="350">
# </p>

# %% [markdown]
# Responda las siguientes preguntas (0.2 pts c/u):
#
# 1. ¿Qué es `Git` y cómo se relaciona con el control de versiones?
#
# 2. Nombre y explique 3 diferencias entre `Git` y `Github`.
#
# 3. ¿Qué es un `hash` y cómo se representa en un `commit`? De un ejemplo.
#
# 4. ¿Que elementos componen a la estructura de datos de `Git`?
#
# 5. ¿Que comandos de `Git` sirven para crear un repositorio y hacer seguimiento a cambios en los archivos?

# %% [markdown]
# 1. Git es un sistema de control de versiones distribuido que permite registrar cambios realizados en uno o más archivos.
#
# 2.  * Git es un sistema de control de versiones distribuido que permite registrar todos los cambios realizados en un archivo y Github es un servicio de alojamiento presente en la web
#
#     * Git es el que crea un repositorio de manera local para así trackear los cambios locales y Github permite subir una copia de los repositorio de Git, teniéndolos así de manera remota
#
#     * Git es una herramienta de línea de comando y Github es una interfaz gráfica que permite trabajar de manera más intuitiva
#
#
#
# 3. Hash es un identificador de 40 carácteres que permite identificar unicamente commits, blobs o trees. En un commit la estructura es la siguiente:
# ```
# commit hash
# Author: ...
# Date: ...
# mensaje del commit
# ```
#
# 4. La unidad basica de almacenamiento en Git son los blobs que contienen la informacion de cada archivo, luego un árbol representa directorios de blobs (o de otros arboles), de esta forma siempre hay un árbol en la raíz apuntando al árbol que contiene cosas. Cuando un archivo se modifica se genera un nuevo blob con los cambios realizados. Finalmente, cada elemento mencionado anteriormente, asi como las modificaciones realizadas en los archivos, son identificadas únicamente con un hash.
#
# 5. **git init** permite crear un repositorio y **git log** se utiliza para observar los commits y merges realizados en los archivos, además se tiene **git status** que indica los archivos nuevos y modificaciones hechas en los archivos que aún no se les ha hecho commit.

# %% [markdown]
# Responda si las siguientes afirmaciones son Verdaderas (V) o Falsas (F). Justifique en **cualquiera** de los casos (0.2 pts c/u):
#
#
# 6. `Git` siempre resuelve automáticamente los problemas de lineas al hacer merge entre diferentes ramas.
# 7. Ejecutar `git pull` sobre un repositorio es equivalente a ejecutar `git clone`.
# 8. `git status` genera los mismos resultados que `git log`.
# 9. En `Git` es posible deshacer cambios y volver a versiones anteriores del código.
# 10. El comando `git commit` se utiliza para enviar cambios al repositorio remoto.

# %% [markdown]
# 6. F. Si bien Git a veces resuelve los problemas de merge, por lo general se deben resolver a mano.
#
# 7. F. Mientras que **git clone** copia un repositorio, **git pull** lo que hace es hacer un merge entre un repositorio local y uno remoto.
#
# 8. F. **git status** muestra el estado actual del repositorio, por ejemplo archivos modificados, untracked o en staged. Por otra parte, **log** lo que hace es mostrar el registro de cambios (estructura de los commit).
#
# 9. V. Se puede hacer mediante **git checkout**, luego para volver a versiones anteriores del código se hace a través del hash del commit al que queramos volver.
#
# 10. F. Para enviar cambios al repositorio remoto se utiliza **git push**.

# %% [markdown]
# Por último, investigue y comente con sus palabras para qué sirven los siguientes comandos:
#
# 11. `git stash` (0.25 puntos)
#
# **R:** **git stash** guarda temporalmente los cambios realizados en el código para luego aplicar estos más tarde.
#
#
# 12. `git reset`. ¿Cuál es la diferencia de este comando con `git revert`?. (0.25 puntos)
#
# **R:** **git reset** lo que hace es reestablecer a un commit anterior y borrar lo que estaba por delante de el, mientas que **git revert** crea un nuevo commit sin alterar su historial.

# %% [markdown]
# ## Parte 2: Creando una presentación personal (1.5 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/arqlNu8gyJYAAAAC/cat-cat-jumping.gif" width="150">
# </p>

# %% [markdown]
# Para empezar a "*soltar las manos*" con `Git`, se les encomienda crear un repositorio con una presentación personal. El repositorio debe contener un breve resumen de quienes son ustedes, sus gustos, experiencias, y cualquier otro detalle interesante que ustedes consideren relevante.
#
# Para realizar esto, deben seguir los siguientes pasos:
#
# 1. Contar con una cuenta de github (1 por persona)
# 2. Crear un repositorio con su nombre de usuario
# 3. Vincular el repositorio a su ambiente local ¿Qué comando(s) me permiten hacer esto?
# 4. Crear un archivo `readme.md` con la información que ustedes deseen compartir.
# 5. Realizar `push` con los cambios generados
#
# A modo de ejemplo, pueden guiarse por esta *suculenta* [presentación](https://github.com/Mezosky)
#
# **Nota: Deben trabajar todos estos puntos desde su ambiente local**
#
# *Hint: Una buena opción es usar templates de presentación personal que encuentren en Google, como los que ofrece este [sitio](https://durgeshsamariya.github.io/awesome-github-profile-readme-templates/#/)*.
#
# **Entregable:**
#
# Enlace al repositorio con la presentación personal.
#
# IMPORTANTE: DEBEN ADJUNTAR UN ENLACE POR PERSONA

# %% [markdown]
# <code>Link Presentacion 1:</code> https://github.com/camilasalasriffo/camilasalasriffo
#
# <code>Link Presentacion 2:</code> https://github.com/ignacio3645/ignacio3645

# %% [markdown]
# ## Parte 3: Trabajando sobre un repositorio externo (2 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/YXL-0SK15j4AAAAC/dance-animals.gif" width="300">
# </p>
#
# Tras muchos dolores de cabeza, un grupo de entusiastas académicos decidieron aprender sobre `Git` y así trabajar colaborativamente de forma más ordenada y eficiente. Después de una infinidad de intentos y aprender de sus errores "*a la mala*", los académicos lograron levantar un [repositorio](https://github.com/MDS7202/lab1) en `Github`. Usando el repositorio de los académicos, responda las siguientes preguntas (**incluya también los comandos en `Git` ocupados**):

# %% [markdown]
# 1. Clone el repositorio a su ambiente local. (0.25 pts)

# %% [markdown]
# el codigo para clonar el repositorio al ambiente local es :
#
# ```
# git clone https://github.com/MDS7202/lab1.git
# ```

# %% [markdown]
# 2. Descomprima los archivos subidos con la tarea en U-cursos en la carpeta recién clonada de github. Una vez realizado esto, cree un archivo `.gitignore` con el cual omita la carpeta `videos` y los archivos con la extensión `.txt` exceptuando el archivo `171.txt` de la carpeta `texts`. (0.25 pts)

# %% [markdown]
# El archivo .gitignore creado tiene la siguiente estructura:
#
# ```
# *videos
# *.txt
# !171.txt
# ```

# %% [markdown]
# 3. Inspeccione brevemente el repositorio: ¿Cual es el objetivo del proyecto? Explique brevemente la estructura del proyecto, asi como también cada elemento que lo conforma. (0.25 pts)

# %% [markdown]
# El repositorio esta conformado por elementos: El primero un "readme" que proporciona un tipo de introduccion/finalidad al proyecto; en segundo lugar una funcion auxiliar que segun un animal proporcionado printea el sonido que este animal emite; Finalmente el main que pide un input y en base a la funcion auxilar "animales.py" entrega el resultado.

# %% [markdown]
# 4. Identifique los últimos cambios al repositorio, reconociendo las principales ramas de trabajo. ¿Son informativos los `commit` realizados? (0.25 pts)
# *Hint: Se recomienda usar los argumentos `all`, `graph` y `decorate`*

# %% [markdown]
# Los ultimos cambios fueron crear 2 ramas "new features" y "fix-ifs", en una de ellas se modularizó el codigo mientras que en otra se corrigió una parte del codigo (pero no se modularizo el codigo). Luego en ninguno de los commits realizados se puede entender con claridad los cambios. pues no se menciona que partes se han modularizado ni tampoco cuales son los errores que se han corregido

# %% [markdown]
# 5. Uno de los académicos se da cuenta que la rama principal de trabajo no se ejecuta correctamente para todos los argumentos. Señale y explique el error en el código e identifique a la persona que lo cometió usando `git blame` (0.25 pts)
#
# *Hint: Le puede ser útil esta [documentación](https://www.atlassian.com/es/git/tutorials/inspecting-a-repository/git-blame).*

# %% [markdown]
# El error esta en utilizar una secuencia de if, en vez de utilizar elif. Por tanto la funcion solo corre sin errrores cuando se entrega como argumento el nombre asociado al ultimo if.
#
# En un principio antes de que se separaran en modulos las funciones ya existia este error cuyo autor fue Sebastian, luego al separar en ramas mezosky realiza un commit que modulariza la funcion anterior y en donde se traspasa el error anterior a los nuevos modulos

# %% [markdown]
# 6. Busque los siguientes `commit`:
#
# - `c8b1a62d7299552b0654f930d695b33109214111`
# - `362fe21ee44f53ee944cee4ba484600308f83d78`
# - `25543a3baf77292baf849726784ca005473acab1`
#
# ¿Qué diferencias existen entre cada uno? (0.25 pts)

# %% [markdown]
# En primer lugar para buscar los commits se utiliza **git show hash**.
# - `c8b1a62d7299552b0654f930d695b33109214111`: Este commit contiene la creación de la función animales junto con la llamada a la función con el input que se pide.
# - `362fe21ee44f53ee944cee4ba484600308f83d78`: Por otra parte, este commit lo que hace es separar en módulos la función animales y la inicialización de la función.
# - `25543a3baf77292baf849726784ca005473acab1`: Finalmente, este commit soluciona el problema mencionado en la pregunta 5 y lo soluciona cambiando el segundo y tercer if por un elif.

# %% [markdown]
# 7. Realice una `merge` de la rama `fix-ifs` con la rama `main` y describa lo que ocurre. ¿Qué parte del código podría estar ocasionando esto? (0.25 pts)

# %% [markdown]
# Al realizar el merge utilizando *git merge origin/fix-ifs*, se puede observar un conflicto en main.py. Esto ocurre porque en la rama principal se ha modularizado el código, y en la rama fix-ifs no, por tanto, al hacer el merge en el archivo main, se han hecho modificaciones distintas en las mismas líneas de código.

# %% [markdown]
# 8. Cree una rama nueva y proponga una solución al problema anterior, adjuntando el código corregido y señalando las líneas modificadas. (0.25 pts)

# %% [markdown]
# La solución consistiría en crear una rama en este caso *git branch correccion*, cambiarnos a esta rama para trabajar en ella con *git checkout correcciones* y al archivo animales.py hacerle las modificaciones que se encontraban en la rama fix-ifs. Una vez hechas las modificaciones, volver a la rama principal con *git checkout main* y fusionarla con la rama que contiene las correcciones como sigue *git merge correcciones -m 'un mensaje que indique el merge que se hace'*. Luego, los cambios realizados en el archivo animales.py fueron los siguientes:
#
# * Original: linea 9 ``` if input.lower() == 'perro': ```,
#             linea 11 ``` if input.lower() == 'fox': ```
#
# * Cambios:  linea 9 ``` elif input.lower() == 'perro': ```
#             linea 11 ``` elif input.lower() == 'fox': ```

# %% [markdown]
# ## Fin

# %% [markdown]
# Eso ha sido todo por ahora!! Esperamos que este laboratorio les haya gustado y servido para trabajar con `Git`. Recuerden los dias de plazo que tienen disponibles y que ante cualquier duda no duden en contactar al equipo docente.
#
# Nos vemos!!
#
# <p align="center">
#   <img src="https://media.tenor.com/OYLdav9k9LkAAAAd/kitty-cat.gif" width="350">
# </p>
